# %% [markdown]
# # Descripción del proyecto
#
# La compañía Sweet Lift Taxi ha recopilado datos históricos sobre pedidos de taxis en los aeropuertos. Para atraer a más conductores durante las horas pico, necesitamos predecir la cantidad de pedidos de taxis para la próxima hora. Construye un modelo para dicha predicción.
#
# La métrica RECM en el conjunto de prueba no debe ser superior a 48.
#
# ## Instrucciones del proyecto.
#
# 1. Descarga los datos y haz el remuestreo por una hora.
# 2. Analiza los datos
# 3. Entrena diferentes modelos con diferentes hiperparámetros. La muestra de prueba debe ser el 10% del conjunto de datos inicial.
# 4. Prueba los datos usando la muestra de prueba y proporciona una conclusión.
#
# ## Descripción de los datos
#
# Los datos se almacenan en el archivo `taxi.csv`.
# El número de pedidos está en la columna `num_orders`.

# %% [markdown]
# ## Preparación

# %% [markdown]
# ### Carga de librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error 
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder, MaxAbsScaler
import lightgbm as lgb
from catboost import Pool, CatBoostRegressor
# Out:
# C:\Users\user\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Carga de datos

# %%
df = pd.read_csv('taxi.csv')

# %% [markdown]
# ### Exploracion de datos

# %%
display(df.head())
print(df.describe())
print()
print(df.info())
# Out:
#               datetime  num_orders
# 0  2018-03-01 00:00:00           9
# 1  2018-03-01 00:10:00          14
# 2  2018-03-01 00:20:00          28
# 3  2018-03-01 00:30:00          20
# 4  2018-03-01 00:40:00          32
#          num_orders
# count  26496.000000
# mean      14.070463
# std        9.211330
# min        0.000000
# 25%        8.000000
# 50%       13.000000
# 75%       19.000000
# max      119.000000
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26496 entries, 0 to 26495
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    26496 non-null  object
#  1   num_orders  26496 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 414.1+ KB
# None

# %%
# Verificamos valores duplicados
df.duplicated().sum()
# Out:
# 0

# %%
df.boxplot('num_orders')
plt.title('Valores de num_orders')
plt.show()

# %% [markdown]
# Observamos de forma rapida que solo tenemos dos columnas de datos: fecha y num de ordenes de taxi, no tenemos valores ausentes ni duplicados.
#
# Necesitamos corregir el tipo de datos de fecha de object a datetime, y observaremos si el porcentaje de valores atipicos que estan por encima del 75% que es 19 ordenes de los datos promedio son anormales o se refieren a las horas pico.

# %%
#Conversion de datos a tipo datetime
df['datetime'] = pd.to_datetime(df['datetime'],format = '%Y-%m-%d %H:%M:%S')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26496 entries, 0 to 26495
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    26496 non-null  datetime64[ns]
#  1   num_orders  26496 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 414.1 KB

# %%
# Porcentaje de valores arriba de 19 ordenes 
print(round((sum(df['num_orders'] > 19)/len(df))*100,2),'% es el porcentaje de la muestra que esta por encima del 75% promedio de los datos, por lo que lo tomaremos\ncomo las horas pico' )
# Out:
# 23.01 % es el porcentaje de la muestra que esta por encima del 75% promedio de los datos, por lo que lo tomaremos
# como las horas pico

# %% [markdown]
# Ya que tenemos nuestra columna de fecha con el tipo correcto "datetime", pasaremos esta columna como indice y la ordenaremos en orden ascendente.

# %%
# Ordenamos nuestros valores de fecha en orden ascendente
df.sort_values(by='datetime',ascending=True, inplace=True)

# Definimos nuestro indice con la columna de datetime
df.set_index('datetime',inplace=True)

# %%
# Verificamos nuestro dataframe
df
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
# ...                         ...
# 2018-08-31 23:10:00          32
# 2018-08-31 23:20:00          24
# 2018-08-31 23:30:00          27
# 2018-08-31 23:40:00          39
# 2018-08-31 23:50:00          53
#
# [26496 rows x 1 columns]

# %% [markdown]
# Podemos observar que tenemos registros comenzando el dia 1 de Marzo de 2018 a las 00:00hrs y finalizando el dia 31 de Agosto de 2018 a las 23:50hrs, lo que nos da un periodo de 6 meses de muestra.
#
# Tenemos nuestros datos listos para poder hacer agrupamientos y posteriormente crear nuestros modelos.

# %% [markdown]
# ## Análisis

# %% [markdown]
# Como observamos en nuestra muestra, nuestros registros estan en intervalos de 10 min y lo que necesitamos es hacer un remuestreo por hora, ya que nuestro objetivo es encontrar el valor medio de taxis por hora, dejaremos el dataframe original y crearemos uno nuevo con el remuestreo realizado.

# %%
# Remuestreo de total de taxis por hora
df1 = df.resample('1H').sum()
df1.plot(figsize=(16,8))
plt.title('Promedio de ordenes de taxi por hora')
plt.show()

# %% [markdown]
# Podemos observar el remuestreo del promedio de ordenes de taxi no es muy claro realicemos un seccionamiento para ver mas de cerca los datos

# %% [markdown]
# ### Tendencias y estacionalidad

# %%
def seasonal_analisis(data):
    decomposed = seasonal_decompose(data)

    plt.figure(figsize=(16, 20))

    plt.subplot(311)
    decomposed.trend.plot(ax=plt.gca())
    plt.title('Tendencia')
    plt.subplot(312)
    decomposed.seasonal.plot(ax=plt.gca())
    plt.title('Estacionalidad')
    plt.subplot(313)
    decomposed.resid.plot(ax=plt.gca())
    plt.title('Residuales')
    plt.tight_layout()
    plt.show()

# %%
def rolling_graf(data,rolling_number):
    x = data
    x['rolling'] = x.rolling(rolling_number).mean()
    x.plot(figsize=(16, 8))
    plt.title('Media movil, taxis por hora')
    plt.show()

# %%
seasonal_analisis(df1)

# %% [markdown]
# Podemos observar que se tiene una tendencia en el aumento de solicitudes de taxis conforme avanza el tiempo y una estacionalidad ciclica, esto aplica para ambos conjuntos de datos, como observamos tenemos el mismo grafico pero con diferentes unidades, de ahora en adelante solo trabajaremos con el conjunto data1 que es el conjunto con el remuestreo con el promedio.
#
# Haremos una muestra de 1 mes para ver como se comporta la tendencia

# %%
seasonal_analisis(df1['2018-03-01':'2018-03-31'])

# %%
rolling_graf(df1['2018-03-01':'2018-03-31'],10)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2800\405181865.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['rolling'] = x.rolling(rolling_number).mean()

# %% [markdown]
# Podemos ver la que tencia en el mes es similar y que tenemos una estacionalidad ciclica, de igual forma podemos ver la media movil de taxis por hora.

# %% [markdown]
# ## Formación

# %% [markdown]
# Comenzaremos con la preparacion y el entrenamiento para nuestros modelos de predicción

# %%
# Haremos un par de pruebas sin entrenar algun modelo
def no_train_test(data,target):
    """Con esta funcion podemos ver los valores de RECM sin utilizar un modelo entrenado con los siguientes argumentos:
    data: conjunto de datos a utilizar
    target: columna de datos objetivo
    """
    train, test = train_test_split(data,shuffle=False,test_size=0.1)
    print('Numero promedio de ordenes de taxi por hora:', round(test[target].mean(),0))
    print()
    pred_mean = pd.Series(train[target].mean(),index = test.index)
    print('RECM con valores constantes')
    print('RECM =', round(mean_squared_error(test,pred_mean,squared=False),0))
    pred_previous = test.shift()
    pred_previous.iloc[0] = train.iloc[-1]
    print()
    print('RECM con valor anterior a la serie')
    print('RECM:', round(mean_squared_error(test[target], pred_previous,squared=False),0))

# %%
no_train_test(df1,'num_orders')
# Out:
# Numero promedio de ordenes de taxi por hora: 140.0
#
# RECM con valores constantes
# RECM = 85.0
#
# RECM con valor anterior a la serie
# RECM: 59.0

# %% [markdown]
# Hemos obtenido valores de RECM de 84 y 59 con dos formas de predecir sin realizar algun modelo, siendo el resultado de 59 un valor "bueno", aun no conseguimos nuestra meta de 48 de RECM; procederemos a realizar entrenamiento de modelos para mejorar esta metrica.

# %% [markdown]
# ### Preparacion de caracteristicas

# %% [markdown]
# Crearemos caracteristicas de calendario, desfase y media movil.

# %%
def make_features(data, max_lag, rolling_mean_size,target):
    """
    Con esta funcion crearemos caracteristicas de calendario(año,mes,dia), asi como hacer el desface de fechas y la media movil
    con los siguientes argumentos:
    data: conjunto de datos
    max_lag: desface maximo
    rolling_mean: media movil
    target: columna objetivo del conjunto data
    """
    data['year'] = data.index.year
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    data['hour'] = data.index.hour
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data[target].shift(lag)

    data['rolling_mean'] = data[target].shift().rolling(rolling_mean_size).mean()

# %%
# Crearemos las caracteristicas
make_features(df1, 4, 4, 'num_orders')

# %%
# comprobamos que se hayan realizado correctamente las caracteriscticas
display(df1.head(10))
print(df1.shape)
# Out:
#                      num_orders  year  month  day  dayofweek  hour  lag_1  \
# datetime
# 2018-03-01 00:00:00         124  2018      3    1          3     0    NaN
# 2018-03-01 01:00:00          85  2018      3    1          3     1  124.0
# 2018-03-01 02:00:00          71  2018      3    1          3     2   85.0
# 2018-03-01 03:00:00          66  2018      3    1          3     3   71.0
# 2018-03-01 04:00:00          43  2018      3    1          3     4   66.0
# 2018-03-01 05:00:00           6  2018      3    1          3     5   43.0
# 2018-03-01 06:00:00          12  2018      3    1          3     6    6.0
# 2018-03-01 07:00:00          15  2018      3    1          3     7   12.0
# 2018-03-01 08:00:00          34  2018      3    1          3     8   15.0
# 2018-03-01 09:00:00          69  2018      3    1          3     9   34.0
#
#                      lag_2  lag_3  lag_4  rolling_mean
# datetime
# 2018-03-01 00:00:00    NaN    NaN    NaN           NaN
# 2018-03-01 01:00:00    NaN    NaN    NaN           NaN
# 2018-03-01 02:00:00  124.0    NaN    NaN           NaN
# 2018-03-01 03:00:00   85.0  124.0    NaN           NaN
# 2018-03-01 04:00:00   71.0   85.0  124.0         86.50
# 2018-03-01 05:00:00   66.0   71.0   85.0         66.25
# 2018-03-01 06:00:00   43.0   66.0   71.0         46.50
# 2018-03-01 07:00:00    6.0   43.0   66.0         31.75
# 2018-03-01 08:00:00   12.0    6.0   43.0         19.00
# 2018-03-01 09:00:00   15.0   12.0    6.0         16.75
# (4416, 11)

# %% [markdown]
# Tenemos que tener en cuenta que un modelo no funciona con valores ausentes, asi que los eliminaremos

# %%
# Eliminacion de valores NaN
df1.dropna(inplace=True)

# %% [markdown]
# Realizaremos el escalamiento de datos para un mejor procesamiento

# %%
# Creamos nuestra funcion de escalado de datos
def maxscaler(data,columns):
    """Con esta funcion realizamos el escalamiento de datos
    data: conjunto de datos a utilizar
    columns: columnas a realizar el escalado de datos
    """
    scaler = MaxAbsScaler()
    scaler.fit(data[columns])
    data[columns] = scaler.transform(data[columns])
    return data[columns]

# %%
maxscaler(df1,['year', 'month', 'day', 'dayofweek','hour', 'lag_1', 'lag_2',
       'lag_3', 'lag_4', 'rolling_mean'])
# Out:
#                      year  month       day  dayofweek      hour     lag_1  \
# datetime
# 2018-03-01 04:00:00   1.0  0.375  0.032258   0.500000  0.173913  0.142857
# 2018-03-01 05:00:00   1.0  0.375  0.032258   0.500000  0.217391  0.093074
# 2018-03-01 06:00:00   1.0  0.375  0.032258   0.500000  0.260870  0.012987
# 2018-03-01 07:00:00   1.0  0.375  0.032258   0.500000  0.304348  0.025974
# 2018-03-01 08:00:00   1.0  0.375  0.032258   0.500000  0.347826  0.032468
# ...                   ...    ...       ...        ...       ...       ...
# 2018-08-31 19:00:00   1.0  1.000  1.000000   0.666667  0.826087  0.448052
# 2018-08-31 20:00:00   1.0  1.000  1.000000   0.666667  0.869565  0.294372
# 2018-08-31 21:00:00   1.0  1.000  1.000000   0.666667  0.913043  0.333333
# 2018-08-31 22:00:00   1.0  1.000  1.000000   0.666667  0.956522  0.344156
# 2018-08-31 23:00:00   1.0  1.000  1.000000   0.666667  1.000000  0.482684
#
#                         lag_2     lag_3     lag_4  rolling_mean
# datetime
# 2018-03-01 04:00:00  0.153680  0.183983  0.268398      0.281072
# 2018-03-01 05:00:00  0.142857  0.153680  0.183983      0.215272
# 2018-03-01 06:00:00  0.093074  0.142857  0.153680      0.151097
# 2018-03-01 07:00:00  0.012987  0.093074  0.142857      0.103168
# 2018-03-01 08:00:00  0.025974  0.012987  0.093074      0.061738
# ...                       ...       ...       ...           ...
# 2018-08-31 19:00:00  0.469697  0.426407  0.251082      0.598700
# 2018-08-31 20:00:00  0.448052  0.469697  0.426407      0.614947
# 2018-08-31 21:00:00  0.294372  0.448052  0.469697      0.580016
# 2018-08-31 22:00:00  0.333333  0.294372  0.448052      0.532900
# 2018-08-31 23:00:00  0.344156  0.333333  0.294372      0.545898
#
# [4412 rows x 10 columns]

# %% [markdown]
# Ya tenemos nuestro conjunto listo para entrenar y evaluar nuestro modelos

# %% [markdown]
# ## Prueba

# %% [markdown]
# ### LinearRegression

# %%
def linear_model(data,target):
    train, test = train_test_split(data, shuffle=False, test_size = 0.1)
    features_train = train.drop(target, axis=1)
    target_train = train[target]
    features_test = test.drop(target, axis=1)
    target_test = test[target]
    model = LinearRegression()
    model.fit(features_train,target_train)
    train_pred = model.predict(features_train)
    test_pred = model.predict(features_test)
    print('RECM para el conjunto de entrenamiento', mean_squared_error(target_train,train_pred,squared=False))
    print('RECM para el conjunto de prueba', mean_squared_error(target_test,test_pred,squared=False))

# %%
linear_model(df1,'num_orders')
# Out:
# RECM para el conjunto de entrenamiento 30.500374252442192
# RECM para el conjunto de prueba 52.574506853736935

# %% [markdown]
# Del model de regresion lineal obtenemos un valor de RECM en el conjunto de prueba de 52, aun un valor alto para nuestro objetivo de 48, intentaremos con otro modelo

# %% [markdown]
# ### DecisionTreeRegressor

# %%
def tree_model(data,target):
    train, test = train_test_split(data, shuffle=False, test_size = 0.1)
    features_train = train.drop(target, axis=1)
    target_train = train[target]
    features_test = test.drop(target, axis=1)
    target_test = test[target]
    
    model = DecisionTreeRegressor(random_state=92)
    param = {'max_depth' : [None, 10],
            'min_samples_leaf': [1,2],
            'min_samples_split':[2,3]}
    gs = GridSearchCV(estimator = model,
                  param_grid = param,
                      scoring = 'neg_root_mean_squared_error',
                  cv = 5)
    gs.fit(features_train,target_train)
    
    train_pred = gs.best_estimator_.predict(features_train)
    test_pred = gs.best_estimator_.predict(features_test)
    
    print('RECM para el conjunto de entrenamiento', mean_squared_error(target_train,train_pred,squared=False))
    print('RECM para el conjunto de prueba', mean_squared_error(target_test,test_pred,squared=False))

# %%
tree_model(df1,'num_orders')
# Out:
# RECM para el conjunto de entrenamiento 16.996013468360996
# RECM para el conjunto de prueba 52.66700307161063

# %% [markdown]
# Tenemos un resultado no muy favorable, un RECM de 52, un resultado similar a la regresion lineal, sigamos intentando

# %% [markdown]
# ### RandomForestRegressor

# %%
def random_model(data,target):
    train, test = train_test_split(data, shuffle=False, test_size = 0.1)
    features_train = train.drop(target, axis=1)
    target_train = train[target]
    features_test = test.drop(target, axis=1)
    target_test = test[target]
    
    model = RandomForestRegressor(random_state=92)
    param = {'n_estimators': [10,100,500],
          'max_depth': [5,10,20],
          'min_samples_split': [3,5],
          'min_samples_leaf': [3,5,10]
            }
    gs = GridSearchCV(estimator = model,
                  param_grid = param,
                      scoring = 'neg_root_mean_squared_error',
                  cv = 5)
    gs.fit(features_train,target_train)
    
    train_pred = gs.best_estimator_.predict(features_train)
    test_pred = gs.best_estimator_.predict(features_test)
    
    print('RECM para el conjunto de entrenamiento', mean_squared_error(target_train,train_pred,squared=False))
    print('RECM para el conjunto de prueba', mean_squared_error(target_test,test_pred,squared=False))

# %%
random_model(df1,'num_orders')
# Out:
# RECM para el conjunto de entrenamiento 12.72753172012084
# RECM para el conjunto de prueba 47.449037139250635

# %% [markdown]
# Tenemos un resultado de RECM de 47.44, con este resultado cumplimos la meta de 48 con 0.5 a nuestro favor, tal vez no es mucho, pero hemos cumlpido.

# %% [markdown]
# ### LightGBM

# %% [markdown]
# #### LightGBM DecisionTree

# %%
def lgbm_tree_regressor(data,target):
    """Con esta funcion se realiza el entrenamiento, prediccion y puntuacion con RECM del modelo de LightGBM, parametros:
    data: conjunto de datos a utilizar
    data_target: objetivo del conjunto
    """
    train, test = train_test_split(data, shuffle=False, test_size = 0.1)
    features_train = train.drop(target, axis=1)
    target_train = train[target]
    features_test = test.drop(target, axis=1)
    target_test = test[target]
    params = {
    'task': 'train', 
    'boosting': 'gbdt',
    'objective': 'regression',
    'num_leaves': 10,
    'learning_rate': 0.05,
    'metric': 'root_mean_squared_error',
    'force_row_wise': True}
    lgb_train = lgb.Dataset(features_train,target_train)
    lgb_eval = lgb.Dataset(features_test,target_test, reference = lgb_train)
    model = lgb.train(params,
                      train_set=lgb_train,
                      valid_sets=lgb_eval)
    train_pred = model.predict(features_train)
    test_pred = model.predict(features_test)
    print('RECM para el conjunto de entrenamiento', mean_squared_error(target_train,train_pred,squared=False))
    print('RECM para el conjunto de prueba', mean_squared_error(target_test,test_pred,squared=False))

# %%
lgbm_tree_regressor(df1,'num_orders')
# Out:
# [LightGBM] [Info] Total Bins 1085
# [LightGBM] [Info] Number of data points in the train set: 3970, number of used features: 9
# [LightGBM] [Info] Start training from score 78.282368
# RECM para el conjunto de entrenamiento 21.348230493305238
# RECM para el conjunto de prueba 47.51336990700879

# %% [markdown]
# Tenemos un resultado de RECM de 47.51, con este resultado cumplimos la meta de 48, con 0.5 a nuestro favor.

# %% [markdown]
# #### LightGBM RandomForestRegressor

# %%
def lgbm_random_regressor(data,target):
    """Con esta funcion se realiza el entrenamiento, prediccion y puntuacion con RECM del modelo de LightGBM, parametros:
    data: conjunto de datos a utilizar
    data_target: objetivo del conjunto
    """
    train, test = train_test_split(data, shuffle=False, test_size = 0.1)
    features_train = train.drop(target, axis=1)
    target_train = train[target]
    features_test = test.drop(target, axis=1)
    target_test = test[target]
    params = {
    'task': 'train', 
    'boosting': 'rf',
    'objective': 'regression',
    'num_leaves': 10,
    'learning_rate': 0.05,
    'metric': 'root_mean_squared_error',
    'force_row_wise': True,
    'bagging_fraction': 0.5,
    'bagging_freq':1,
    'feature_fraction':0.9}
    lgb_train = lgb.Dataset(features_train,target_train)
    lgb_eval = lgb.Dataset(features_test,target_test, reference = lgb_train)
    model = lgb.train(params,
                 train_set=lgb_train,
                 valid_sets=lgb_eval)
    train_pred = model.predict(features_train)
    test_pred = model.predict(features_test)
    print('RECM para el conjunto de entrenamiento', mean_squared_error(target_train,train_pred,squared=False))
    print('RECM para el conjunto de prueba', mean_squared_error(target_test,test_pred,squared=False))

# %%
lgbm_random_regressor(df1,'num_orders')
# Out:
# [LightGBM] [Info] Total Bins 1085
# [LightGBM] [Info] Number of data points in the train set: 3970, number of used features: 9
# [LightGBM] [Info] Start training from score 78.282368
# RECM para el conjunto de entrenamiento 26.24355984982914
# RECM para el conjunto de prueba 58.00473389813856

# %% [markdown]
# Tenemos un resultado de RECM de 58, muy alejado de nuestra meta de 48 y aun mayor que el resultado de la regresion lineal, este es un modelo que no consideraremos en un futuro.

# %% [markdown]
# ### Catboost

# %%
def catboost_regressor(data,target):
    """Con esta funcion se realiza el entrenamiento, prediccion y puntuacion con RECM del modelo de catboostregressor, parametros:
    data: conjunto de datos a utilizar
    target: objetivo del conjunto
    """
    train, test = train_test_split(data, shuffle=False, test_size = 0.1)
    features_train = train.drop(target, axis=1)
    target_train = train[target]
    features_test = test.drop(target, axis=1)
    target_test = test[target]
    model = CatBoostRegressor(random_state=92)
    model.fit(features_train,target_train)
    train_pred = model.predict(features_train)
    test_pred = model.predict(features_test)
    print('RECM para el conjunto de entrenamiento', mean_squared_error(target_train,train_pred,squared=False))
    print('RECM para el conjunto de prueba', mean_squared_error(target_test,test_pred,squared=False))

# %%
catboost_regressor(df1,'num_orders')
# Out:
# Learning rate set to 0.050908
# 0:	learn: 37.7534588	total: 149ms	remaining: 2m 29s
# 1:	learn: 36.8873787	total: 155ms	remaining: 1m 17s
# 2:	learn: 36.1199292	total: 160ms	remaining: 53.1s
# 3:	learn: 35.3313486	total: 164ms	remaining: 40.9s
# 4:	learn: 34.6307489	total: 166ms	remaining: 33.1s
# 5:	learn: 34.0011761	total: 168ms	remaining: 27.8s
# 6:	learn: 33.4287368	total: 169ms	remaining: 23.9s
# 7:	learn: 32.7822681	total: 170ms	remaining: 21.1s
# 8:	learn: 32.3092181	total: 171ms	remaining: 18.9s
# 9:	learn: 31.8364387	total: 173ms	remaining: 17.1s
# 10:	learn: 31.3690001	total: 174ms	remaining: 15.6s
# 11:	learn: 30.8838725	total: 175ms	remaining: 14.4s
# 12:	learn: 30.5004671	total: 177ms	remaining: 13.4s
# 13:	learn: 30.1335588	total: 178ms	remaining: 12.5s
# 14:	learn: 29.8089028	total: 179ms	remaining: 11.8s
# 15:	learn: 29.5075873	total: 181ms	remaining: 11.1s
# 16:	learn: 29.2282777	total: 182ms	remaining: 10.6s
# 17:	learn: 28.9518898	total: 184ms	remaining: 10s
# 18:	learn: 28.6273292	total: 185ms	remaining: 9.55s
# 19:	learn: 28.4117657	total: 186ms	remaining: 9.13s
# 20:	learn: 28.1260801	total: 188ms	remaining: 8.74s
# 21:	learn: 27.8747860	total: 189ms	remaining: 8.4s
# 22:	learn: 27.6241992	total: 190ms	remaining: 8.09s
# 23:	learn: 27.4205323	total: 192ms	remaining: 7.8s
# 24:	learn: 27.2188731	total: 193ms	remaining: 7.53s
# 25:	learn: 27.0369755	total: 194ms	remaining: 7.28s
# 26:	learn: 26.8261206	total: 196ms	remaining: 7.06s
# 27:	learn: 26.7228206	total: 197ms	remaining: 6.85s
# 28:	learn: 26.5288147	total: 199ms	remaining: 6.65s
# 29:	learn: 26.3811389	total: 200ms	remaining: 6.46s
# 30:	learn: 26.2302662	total: 201ms	remaining: 6.29s
# 31:	learn: 26.0659321	total: 203ms	remaining: 6.14s
# 32:	learn: 25.9427495	total: 204ms	remaining: 5.99s
# 33:	learn: 25.7916653	total: 206ms	remaining: 5.84s
# 34:	learn: 25.6575370	total: 207ms	remaining: 5.71s
# 35:	learn: 25.5114497	total: 208ms	remaining: 5.58s
# 36:	learn: 25.3862089	total: 210ms	remaining: 5.46s
# 37:	learn: 25.2836185	total: 211ms	remaining: 5.35s
# 38:	learn: 25.1850512	total: 213ms	remaining: 5.24s
# 39:	learn: 25.1082980	total: 214ms	remaining: 5.14s
# 40:	learn: 25.0140868	total: 216ms	remaining: 5.05s
# 41:	learn: 24.9018214	total: 217ms	remaining: 4.96s
# 42:	learn: 24.8175155	total: 219ms	remaining: 4.87s
# 43:	learn: 24.7334288	total: 220ms	remaining: 4.78s
# 44:	learn: 24.6832542	total: 221ms	remaining: 4.7s
# 45:	learn: 24.5682552	total: 223ms	remaining: 4.63s
# 46:	learn: 24.5033387	total: 225ms	remaining: 4.56s
# 47:	learn: 24.4388833	total: 226ms	remaining: 4.49s
# 48:	learn: 24.3693134	total: 228ms	remaining: 4.42s
# 49:	learn: 24.3319081	total: 229ms	remaining: 4.36s
# 50:	learn: 24.2777061	total: 231ms	remaining: 4.29s
# 51:	learn: 24.2679999	total: 232ms	remaining: 4.23s
# 52:	learn: 24.1834372	total: 233ms	remaining: 4.17s
# 53:	learn: 24.1663334	total: 234ms	remaining: 4.11s
# 54:	learn: 24.1054398	total: 236ms	remaining: 4.05s
# 55:	learn: 24.0217287	total: 237ms	remaining: 3.99s
# 56:	learn: 23.9772422	total: 238ms	remaining: 3.94s
# 57:	learn: 23.9155039	total: 240ms	remaining: 3.89s
# 58:	learn: 23.8892337	total: 241ms	remaining: 3.85s
# 59:	learn: 23.8728339	total: 242ms	remaining: 3.8s
# 60:	learn: 23.8459196	total: 244ms	remaining: 3.75s
# 61:	learn: 23.7876858	total: 245ms	remaining: 3.71s
# 62:	learn: 23.7303241	total: 246ms	remaining: 3.66s
# 63:	learn: 23.7181197	total: 248ms	remaining: 3.62s
# 64:	learn: 23.6959184	total: 249ms	remaining: 3.58s
# 65:	learn: 23.6777352	total: 250ms	remaining: 3.54s
# 66:	learn: 23.6304485	total: 252ms	remaining: 3.5s
# 67:	learn: 23.5716549	total: 253ms	remaining: 3.46s
# 68:	learn: 23.5385072	total: 254ms	remaining: 3.43s
# 69:	learn: 23.5116066	total: 255ms	remaining: 3.39s
# 70:	learn: 23.5055021	total: 257ms	remaining: 3.36s
# 71:	learn: 23.4544425	total: 258ms	remaining: 3.32s
# 72:	learn: 23.3724194	total: 259ms	remaining: 3.29s
# 73:	learn: 23.2926701	total: 260ms	remaining: 3.26s
# 74:	learn: 23.2068182	total: 262ms	remaining: 3.23s
# 75:	learn: 23.1378260	total: 263ms	remaining: 3.2s
# 76:	learn: 23.1209513	total: 264ms	remaining: 3.17s
# 77:	learn: 23.0906181	total: 265ms	remaining: 3.14s
# 78:	learn: 23.0538789	total: 267ms	remaining: 3.11s
# 79:	learn: 23.0142184	total: 268ms	remaining: 3.08s
# 80:	learn: 23.0075007	total: 269ms	remaining: 3.05s
# 81:	learn: 22.9583145	total: 271ms	remaining: 3.03s
# 82:	learn: 22.9137301	total: 272ms	remaining: 3s
# 83:	learn: 22.9010827	total: 273ms	remaining: 2.98s
# 84:	learn: 22.8666072	total: 274ms	remaining: 2.95s
# 85:	learn: 22.8480530	total: 276ms	remaining: 2.93s
# 86:	learn: 22.8172177	total: 277ms	remaining: 2.9s
# 87:	learn: 22.8019091	total: 278ms	remaining: 2.88s
# 88:	learn: 22.7905716	total: 279ms	remaining: 2.86s
# 89:	learn: 22.7637072	total: 281ms	remaining: 2.84s
# 90:	learn: 22.7062224	total: 282ms	remaining: 2.82s
# 91:	learn: 22.6867240	total: 283ms	remaining: 2.79s
# 92:	learn: 22.6280354	total: 284ms	remaining: 2.77s
# 93:	learn: 22.5740611	total: 286ms	remaining: 2.75s
# 94:	learn: 22.5378293	total: 287ms	remaining: 2.73s
# 95:	learn: 22.5300629	total: 288ms	remaining: 2.71s
# 96:	learn: 22.5028680	total: 289ms	remaining: 2.69s
# 97:	learn: 22.4944304	total: 290ms	remaining: 2.67s
# 98:	learn: 22.4308072	total: 292ms	remaining: 2.65s
# 99:	learn: 22.4017823	total: 293ms	remaining: 2.63s
# 100:	learn: 22.3630683	total: 294ms	remaining: 2.62s
# 101:	learn: 22.3262247	total: 295ms	remaining: 2.6s
# 102:	learn: 22.2962613	total: 297ms	remaining: 2.58s
# 103:	learn: 22.2919306	total: 298ms	remaining: 2.56s
# 104:	learn: 22.2574348	total: 299ms	remaining: 2.55s
# 105:	learn: 22.2310864	total: 300ms	remaining: 2.53s
# 106:	learn: 22.2135764	total: 301ms	remaining: 2.51s
# 107:	learn: 22.1916460	total: 303ms	remaining: 2.5s
# 108:	learn: 22.1713986	total: 304ms	remaining: 2.48s
# 109:	learn: 22.1207647	total: 305ms	remaining: 2.47s
# 110:	learn: 22.1002323	total: 306ms	remaining: 2.45s
# 111:	learn: 22.0450646	total: 308ms	remaining: 2.44s
# 112:	learn: 22.0293596	total: 309ms	remaining: 2.42s
# 113:	learn: 22.0203630	total: 310ms	remaining: 2.41s
# 114:	learn: 22.0057680	total: 311ms	remaining: 2.4s
# 115:	learn: 21.9895198	total: 313ms	remaining: 2.38s
# 116:	learn: 21.9723323	total: 314ms	remaining: 2.37s
# 117:	learn: 21.9382979	total: 315ms	remaining: 2.35s
# 118:	learn: 21.8944870	total: 316ms	remaining: 2.34s
# 119:	learn: 21.8909626	total: 317ms	remaining: 2.33s
# 120:	learn: 21.8640518	total: 318ms	remaining: 2.31s
# 121:	learn: 21.8525383	total: 320ms	remaining: 2.3s
# 122:	learn: 21.8493227	total: 320ms	remaining: 2.28s
# 123:	learn: 21.7927854	total: 321ms	remaining: 2.27s
# 124:	learn: 21.7477719	total: 323ms	remaining: 2.26s
# 125:	learn: 21.7442252	total: 324ms	remaining: 2.25s
# 126:	learn: 21.7208451	total: 325ms	remaining: 2.23s
# 127:	learn: 21.7034021	total: 326ms	remaining: 2.22s
# 128:	learn: 21.6808073	total: 328ms	remaining: 2.21s
# 129:	learn: 21.6533494	total: 329ms	remaining: 2.2s
# 130:	learn: 21.6301232	total: 330ms	remaining: 2.19s
# 131:	learn: 21.5922856	total: 332ms	remaining: 2.18s
# 132:	learn: 21.5511623	total: 333ms	remaining: 2.17s
# 133:	learn: 21.5409763	total: 334ms	remaining: 2.16s
# 134:	learn: 21.5162602	total: 336ms	remaining: 2.15s
# 135:	learn: 21.4790068	total: 337ms	remaining: 2.14s
# 136:	learn: 21.4327359	total: 339ms	remaining: 2.13s
# 137:	learn: 21.3929892	total: 340ms	remaining: 2.12s
# 138:	learn: 21.3647249	total: 342ms	remaining: 2.12s
# 139:	learn: 21.3550669	total: 343ms	remaining: 2.11s
# 140:	learn: 21.3252455	total: 344ms	remaining: 2.1s
# 141:	learn: 21.2914374	total: 346ms	remaining: 2.09s
# 142:	learn: 21.2834077	total: 347ms	remaining: 2.08s
# 143:	learn: 21.2591504	total: 348ms	remaining: 2.07s
# 144:	learn: 21.2318541	total: 350ms	remaining: 2.06s
# 145:	learn: 21.2206801	total: 351ms	remaining: 2.05s
# 146:	learn: 21.1934563	total: 352ms	remaining: 2.04s
# 147:	learn: 21.1526470	total: 354ms	remaining: 2.04s
# 148:	learn: 21.1404013	total: 355ms	remaining: 2.03s
# 149:	learn: 21.0992171	total: 356ms	remaining: 2.02s
# 150:	learn: 21.0672240	total: 357ms	remaining: 2.01s
# 151:	learn: 21.0457808	total: 359ms	remaining: 2s
# 152:	learn: 21.0387608	total: 360ms	remaining: 1.99s
# 153:	learn: 21.0239339	total: 361ms	remaining: 1.98s
# 154:	learn: 21.0148946	total: 362ms	remaining: 1.98s
# 155:	learn: 20.9659732	total: 364ms	remaining: 1.97s
# 156:	learn: 20.9574661	total: 365ms	remaining: 1.96s
# 157:	learn: 20.9527419	total: 366ms	remaining: 1.95s
# 158:	learn: 20.9089431	total: 368ms	remaining: 1.94s
# 159:	learn: 20.8709025	total: 369ms	remaining: 1.94s
# 160:	learn: 20.8458106	total: 370ms	remaining: 1.93s
# 161:	learn: 20.8225310	total: 371ms	remaining: 1.92s
# 162:	learn: 20.7983965	total: 373ms	remaining: 1.91s
# 163:	learn: 20.7939230	total: 374ms	remaining: 1.91s
# 164:	learn: 20.7910425	total: 375ms	remaining: 1.9s
# 165:	learn: 20.7579659	total: 377ms	remaining: 1.89s
# 166:	learn: 20.7540506	total: 378ms	remaining: 1.88s
# 167:	learn: 20.7188751	total: 379ms	remaining: 1.88s
# 168:	learn: 20.6956425	total: 380ms	remaining: 1.87s
# 169:	learn: 20.6589496	total: 382ms	remaining: 1.86s
# 170:	learn: 20.6559195	total: 383ms	remaining: 1.85s
# 171:	learn: 20.6465000	total: 384ms	remaining: 1.85s
# 172:	learn: 20.6202112	total: 385ms	remaining: 1.84s
# 173:	learn: 20.5910047	total: 386ms	remaining: 1.83s
# 174:	learn: 20.5722509	total: 388ms	remaining: 1.83s
# 175:	learn: 20.5530480	total: 389ms	remaining: 1.82s
# 176:	learn: 20.5497328	total: 390ms	remaining: 1.81s
# 177:	learn: 20.5396412	total: 391ms	remaining: 1.81s
# 178:	learn: 20.5325600	total: 393ms	remaining: 1.8s
# 179:	learn: 20.5092031	total: 395ms	remaining: 1.8s
# 180:	learn: 20.5058456	total: 396ms	remaining: 1.79s
# 181:	learn: 20.4741700	total: 397ms	remaining: 1.78s
# 182:	learn: 20.4646436	total: 398ms	remaining: 1.78s
# 183:	learn: 20.4204381	total: 400ms	remaining: 1.77s
# 184:	learn: 20.4186311	total: 400ms	remaining: 1.76s
# 185:	learn: 20.4153578	total: 402ms	remaining: 1.76s
# 186:	learn: 20.4084085	total: 403ms	remaining: 1.75s
# 187:	learn: 20.4057071	total: 404ms	remaining: 1.74s
# 188:	learn: 20.4027560	total: 405ms	remaining: 1.74s
# 189:	learn: 20.3617097	total: 407ms	remaining: 1.73s
# 190:	learn: 20.3471241	total: 408ms	remaining: 1.73s
# 191:	learn: 20.3461788	total: 409ms	remaining: 1.72s
# 192:	learn: 20.3332951	total: 410ms	remaining: 1.71s
# 193:	learn: 20.3100093	total: 411ms	remaining: 1.71s
# 194:	learn: 20.3060683	total: 413ms	remaining: 1.7s
# 195:	learn: 20.2766809	total: 414ms	remaining: 1.7s
# 196:	learn: 20.2721486	total: 416ms	remaining: 1.69s
# 197:	learn: 20.2531369	total: 417ms	remaining: 1.69s
# 198:	learn: 20.2388886	total: 418ms	remaining: 1.68s
# 199:	learn: 20.2327930	total: 420ms	remaining: 1.68s
# 200:	learn: 20.2008610	total: 421ms	remaining: 1.67s
# 201:	learn: 20.1980635	total: 422ms	remaining: 1.67s
# 202:	learn: 20.1898588	total: 424ms	remaining: 1.66s
# 203:	learn: 20.1593438	total: 425ms	remaining: 1.66s
# 204:	learn: 20.1287221	total: 426ms	remaining: 1.65s
# 205:	learn: 20.1185145	total: 428ms	remaining: 1.65s
# 206:	learn: 20.1162726	total: 429ms	remaining: 1.64s
# 207:	learn: 20.0901034	total: 430ms	remaining: 1.64s
# 208:	learn: 20.0701569	total: 432ms	remaining: 1.63s
# 209:	learn: 20.0559013	total: 433ms	remaining: 1.63s
# 210:	learn: 20.0471681	total: 434ms	remaining: 1.62s
# 211:	learn: 20.0364059	total: 435ms	remaining: 1.62s
# 212:	learn: 20.0201917	total: 437ms	remaining: 1.61s
# 213:	learn: 20.0180778	total: 438ms	remaining: 1.61s
# 214:	learn: 20.0160044	total: 439ms	remaining: 1.6s
# 215:	learn: 19.9755580	total: 440ms	remaining: 1.6s
# 216:	learn: 19.9664397	total: 442ms	remaining: 1.59s
# 217:	learn: 19.9560033	total: 443ms	remaining: 1.59s
# 218:	learn: 19.9339280	total: 444ms	remaining: 1.58s
# 219:	learn: 19.9055039	total: 445ms	remaining: 1.58s
# 220:	learn: 19.8822799	total: 447ms	remaining: 1.57s
# 221:	learn: 19.8687942	total: 448ms	remaining: 1.57s
# 222:	learn: 19.8547709	total: 449ms	remaining: 1.56s
# 223:	learn: 19.8227051	total: 450ms	remaining: 1.56s
# 224:	learn: 19.7948856	total: 452ms	remaining: 1.56s
# 225:	learn: 19.7747248	total: 453ms	remaining: 1.55s
# 226:	learn: 19.7719453	total: 454ms	remaining: 1.55s
# 227:	learn: 19.7511324	total: 456ms	remaining: 1.54s
# 228:	learn: 19.7236161	total: 457ms	remaining: 1.54s
# 229:	learn: 19.7122435	total: 458ms	remaining: 1.53s
# 230:	learn: 19.6893723	total: 459ms	remaining: 1.53s
# 231:	learn: 19.6658764	total: 461ms	remaining: 1.52s
# 232:	learn: 19.6631463	total: 462ms	remaining: 1.52s
# 233:	learn: 19.6498549	total: 463ms	remaining: 1.51s
# 234:	learn: 19.6372486	total: 464ms	remaining: 1.51s
# 235:	learn: 19.6125813	total: 466ms	remaining: 1.51s
# 236:	learn: 19.5976651	total: 467ms	remaining: 1.5s
# 237:	learn: 19.5846928	total: 468ms	remaining: 1.5s
# 238:	learn: 19.5805405	total: 469ms	remaining: 1.49s
# 239:	learn: 19.5770765	total: 471ms	remaining: 1.49s
# 240:	learn: 19.5658992	total: 472ms	remaining: 1.49s
# 241:	learn: 19.5335785	total: 473ms	remaining: 1.48s
# 242:	learn: 19.5107660	total: 475ms	remaining: 1.48s
# 243:	learn: 19.4805403	total: 476ms	remaining: 1.47s
# 244:	learn: 19.4632282	total: 477ms	remaining: 1.47s
# 245:	learn: 19.4416425	total: 478ms	remaining: 1.47s
# 246:	learn: 19.4203015	total: 480ms	remaining: 1.46s
# 247:	learn: 19.4104534	total: 481ms	remaining: 1.46s
# 248:	learn: 19.3915462	total: 482ms	remaining: 1.45s
# 249:	learn: 19.3706969	total: 484ms	remaining: 1.45s
# 250:	learn: 19.3489644	total: 485ms	remaining: 1.45s
# 251:	learn: 19.3371415	total: 486ms	remaining: 1.44s
# 252:	learn: 19.3066443	total: 487ms	remaining: 1.44s
# 253:	learn: 19.3055449	total: 489ms	remaining: 1.44s
# 254:	learn: 19.2808357	total: 490ms	remaining: 1.43s
# 255:	learn: 19.2623503	total: 491ms	remaining: 1.43s
# 256:	learn: 19.2383171	total: 492ms	remaining: 1.42s
# 257:	learn: 19.2289733	total: 494ms	remaining: 1.42s
# 258:	learn: 19.2273683	total: 495ms	remaining: 1.42s
# 259:	learn: 19.2166967	total: 496ms	remaining: 1.41s
# 260:	learn: 19.2079799	total: 497ms	remaining: 1.41s
# 261:	learn: 19.1893601	total: 499ms	remaining: 1.4s
# 262:	learn: 19.1683533	total: 500ms	remaining: 1.4s
# 263:	learn: 19.1492707	total: 501ms	remaining: 1.4s
# 264:	learn: 19.1235283	total: 503ms	remaining: 1.39s
# 265:	learn: 19.0961523	total: 504ms	remaining: 1.39s
# 266:	learn: 19.0692197	total: 505ms	remaining: 1.39s
# 267:	learn: 19.0651689	total: 506ms	remaining: 1.38s
# 268:	learn: 19.0442852	total: 508ms	remaining: 1.38s
# 269:	learn: 19.0372536	total: 509ms	remaining: 1.38s
# 270:	learn: 19.0148800	total: 510ms	remaining: 1.37s
# 271:	learn: 18.9852849	total: 512ms	remaining: 1.37s
# 272:	learn: 18.9813616	total: 513ms	remaining: 1.37s
# 273:	learn: 18.9602563	total: 514ms	remaining: 1.36s
# 274:	learn: 18.9566134	total: 516ms	remaining: 1.36s
# 275:	learn: 18.9523807	total: 517ms	remaining: 1.35s
# 276:	learn: 18.9439923	total: 518ms	remaining: 1.35s
# 277:	learn: 18.9229064	total: 519ms	remaining: 1.35s
# 278:	learn: 18.9072189	total: 521ms	remaining: 1.34s
# 279:	learn: 18.8840440	total: 522ms	remaining: 1.34s
# 280:	learn: 18.8700915	total: 523ms	remaining: 1.34s
# 281:	learn: 18.8503120	total: 525ms	remaining: 1.33s
# 282:	learn: 18.8391568	total: 526ms	remaining: 1.33s
# 283:	learn: 18.8365061	total: 528ms	remaining: 1.33s
# 284:	learn: 18.8235756	total: 529ms	remaining: 1.33s
# 285:	learn: 18.8036047	total: 531ms	remaining: 1.32s
# 286:	learn: 18.7872630	total: 532ms	remaining: 1.32s
# 287:	learn: 18.7846366	total: 534ms	remaining: 1.32s
# 288:	learn: 18.7683170	total: 535ms	remaining: 1.31s
# 289:	learn: 18.7521075	total: 536ms	remaining: 1.31s
# 290:	learn: 18.7439755	total: 538ms	remaining: 1.31s
# 291:	learn: 18.7290849	total: 539ms	remaining: 1.31s
# 292:	learn: 18.7225270	total: 540ms	remaining: 1.3s
# 293:	learn: 18.7184919	total: 542ms	remaining: 1.3s
# 294:	learn: 18.6949299	total: 543ms	remaining: 1.3s
# 295:	learn: 18.6830362	total: 544ms	remaining: 1.29s
# 296:	learn: 18.6637379	total: 545ms	remaining: 1.29s
# 297:	learn: 18.6426654	total: 547ms	remaining: 1.29s
# 298:	learn: 18.6365581	total: 548ms	remaining: 1.28s
# 299:	learn: 18.6195609	total: 549ms	remaining: 1.28s
# 300:	learn: 18.5984441	total: 551ms	remaining: 1.28s
# 301:	learn: 18.5883148	total: 552ms	remaining: 1.27s
# 302:	learn: 18.5808347	total: 553ms	remaining: 1.27s
# 303:	learn: 18.5736736	total: 554ms	remaining: 1.27s
# 304:	learn: 18.5611587	total: 556ms	remaining: 1.27s
# 305:	learn: 18.5578219	total: 557ms	remaining: 1.26s
# 306:	learn: 18.5506920	total: 558ms	remaining: 1.26s
# 307:	learn: 18.5284493	total: 559ms	remaining: 1.26s
# 308:	learn: 18.5244597	total: 561ms	remaining: 1.25s
# 309:	learn: 18.5098166	total: 562ms	remaining: 1.25s
# 310:	learn: 18.4938931	total: 563ms	remaining: 1.25s
# 311:	learn: 18.4724087	total: 564ms	remaining: 1.24s
# 312:	learn: 18.4632552	total: 566ms	remaining: 1.24s
# 313:	learn: 18.4602545	total: 567ms	remaining: 1.24s
# 314:	learn: 18.4435206	total: 568ms	remaining: 1.24s
# 315:	learn: 18.4266336	total: 570ms	remaining: 1.23s
# 316:	learn: 18.4198307	total: 571ms	remaining: 1.23s
# 317:	learn: 18.4062846	total: 572ms	remaining: 1.23s
# 318:	learn: 18.3890336	total: 573ms	remaining: 1.22s
# 319:	learn: 18.3700951	total: 575ms	remaining: 1.22s
# 320:	learn: 18.3523152	total: 576ms	remaining: 1.22s
# 321:	learn: 18.3371301	total: 577ms	remaining: 1.22s
# 322:	learn: 18.3216562	total: 578ms	remaining: 1.21s
# 323:	learn: 18.3068230	total: 580ms	remaining: 1.21s
# 324:	learn: 18.2904634	total: 581ms	remaining: 1.21s
# 325:	learn: 18.2799125	total: 582ms	remaining: 1.2s
# 326:	learn: 18.2633577	total: 584ms	remaining: 1.2s
# 327:	learn: 18.2442194	total: 586ms	remaining: 1.2s
# 328:	learn: 18.2307226	total: 587ms	remaining: 1.2s
# 329:	learn: 18.2260016	total: 588ms	remaining: 1.19s
# 330:	learn: 18.2070804	total: 590ms	remaining: 1.19s
# 331:	learn: 18.1946220	total: 591ms	remaining: 1.19s
# 332:	learn: 18.1780531	total: 593ms	remaining: 1.19s
# 333:	learn: 18.1593284	total: 594ms	remaining: 1.18s
# 334:	learn: 18.1473244	total: 595ms	remaining: 1.18s
# 335:	learn: 18.1367381	total: 597ms	remaining: 1.18s
# 336:	learn: 18.1256978	total: 598ms	remaining: 1.18s
# 337:	learn: 18.1129115	total: 599ms	remaining: 1.17s
# 338:	learn: 18.1016848	total: 601ms	remaining: 1.17s
# 339:	learn: 18.0934863	total: 602ms	remaining: 1.17s
# 340:	learn: 18.0788553	total: 604ms	remaining: 1.17s
# 341:	learn: 18.0622355	total: 605ms	remaining: 1.16s
# 342:	learn: 18.0470364	total: 606ms	remaining: 1.16s
# 343:	learn: 18.0300008	total: 608ms	remaining: 1.16s
# 344:	learn: 18.0175823	total: 609ms	remaining: 1.16s
# 345:	learn: 18.0076441	total: 610ms	remaining: 1.15s
# 346:	learn: 18.0010167	total: 612ms	remaining: 1.15s
# 347:	learn: 17.9933604	total: 613ms	remaining: 1.15s
# 348:	learn: 17.9741750	total: 614ms	remaining: 1.15s
# 349:	learn: 17.9659085	total: 616ms	remaining: 1.14s
# 350:	learn: 17.9591687	total: 617ms	remaining: 1.14s
# 351:	learn: 17.9497738	total: 618ms	remaining: 1.14s
# 352:	learn: 17.9469877	total: 619ms	remaining: 1.14s
# 353:	learn: 17.9336873	total: 621ms	remaining: 1.13s
# 354:	learn: 17.9178273	total: 622ms	remaining: 1.13s
# 355:	learn: 17.9008504	total: 623ms	remaining: 1.13s
# 356:	learn: 17.8885303	total: 624ms	remaining: 1.12s
# 357:	learn: 17.8807453	total: 626ms	remaining: 1.12s
# 358:	learn: 17.8636986	total: 627ms	remaining: 1.12s
# 359:	learn: 17.8415612	total: 628ms	remaining: 1.12s
# 360:	learn: 17.8276934	total: 630ms	remaining: 1.11s
# 361:	learn: 17.8112465	total: 631ms	remaining: 1.11s
# 362:	learn: 17.7953380	total: 632ms	remaining: 1.11s
# 363:	learn: 17.7814361	total: 633ms	remaining: 1.11s
# 364:	learn: 17.7658990	total: 635ms	remaining: 1.1s
# 365:	learn: 17.7536628	total: 636ms	remaining: 1.1s
# 366:	learn: 17.7529888	total: 637ms	remaining: 1.1s
# 367:	learn: 17.7412402	total: 638ms	remaining: 1.1s
# 368:	learn: 17.7302891	total: 640ms	remaining: 1.09s
# 369:	learn: 17.7108541	total: 641ms	remaining: 1.09s
# 370:	learn: 17.7035041	total: 642ms	remaining: 1.09s
# 371:	learn: 17.6887500	total: 643ms	remaining: 1.09s
# 372:	learn: 17.6770983	total: 645ms	remaining: 1.08s
# 373:	learn: 17.6719106	total: 646ms	remaining: 1.08s
# 374:	learn: 17.6556842	total: 647ms	remaining: 1.08s
# 375:	learn: 17.6396235	total: 648ms	remaining: 1.08s
# 376:	learn: 17.6246208	total: 650ms	remaining: 1.07s
# 377:	learn: 17.6123123	total: 651ms	remaining: 1.07s
# 378:	learn: 17.6027797	total: 652ms	remaining: 1.07s
# 379:	learn: 17.5890264	total: 654ms	remaining: 1.07s
# 380:	learn: 17.5859864	total: 655ms	remaining: 1.06s
# 381:	learn: 17.5690054	total: 656ms	remaining: 1.06s
# 382:	learn: 17.5599619	total: 658ms	remaining: 1.06s
# 383:	learn: 17.5467176	total: 659ms	remaining: 1.06s
# 384:	learn: 17.5401008	total: 661ms	remaining: 1.05s
# 385:	learn: 17.5282504	total: 662ms	remaining: 1.05s
# 386:	learn: 17.5166945	total: 664ms	remaining: 1.05s
# 387:	learn: 17.5055431	total: 665ms	remaining: 1.05s
# 388:	learn: 17.4918102	total: 666ms	remaining: 1.05s
# 389:	learn: 17.4838491	total: 668ms	remaining: 1.04s
# 390:	learn: 17.4701695	total: 669ms	remaining: 1.04s
# 391:	learn: 17.4614130	total: 670ms	remaining: 1.04s
# 392:	learn: 17.4552479	total: 671ms	remaining: 1.04s
# 393:	learn: 17.4488018	total: 673ms	remaining: 1.03s
# 394:	learn: 17.4431217	total: 674ms	remaining: 1.03s
# 395:	learn: 17.4270280	total: 675ms	remaining: 1.03s
# 396:	learn: 17.4091836	total: 676ms	remaining: 1.03s
# 397:	learn: 17.3963086	total: 678ms	remaining: 1.02s
# 398:	learn: 17.3846842	total: 679ms	remaining: 1.02s
# 399:	learn: 17.3709092	total: 680ms	remaining: 1.02s
# 400:	learn: 17.3544652	total: 682ms	remaining: 1.02s
# 401:	learn: 17.3401703	total: 683ms	remaining: 1.01s
# 402:	learn: 17.3270987	total: 684ms	remaining: 1.01s
# 403:	learn: 17.3165010	total: 685ms	remaining: 1.01s
# 404:	learn: 17.3061048	total: 687ms	remaining: 1.01s
# 405:	learn: 17.3016150	total: 688ms	remaining: 1.01s
# 406:	learn: 17.2952819	total: 689ms	remaining: 1s
# 407:	learn: 17.2824837	total: 691ms	remaining: 1s
# 408:	learn: 17.2674800	total: 692ms	remaining: 1000ms
# 409:	learn: 17.2588585	total: 693ms	remaining: 997ms
# 410:	learn: 17.2487404	total: 694ms	remaining: 995ms
# 411:	learn: 17.2328797	total: 696ms	remaining: 993ms
# 412:	learn: 17.2186019	total: 697ms	remaining: 991ms
# 413:	learn: 17.1993101	total: 698ms	remaining: 988ms
# 414:	learn: 17.1986464	total: 699ms	remaining: 986ms
# 415:	learn: 17.1812955	total: 701ms	remaining: 984ms
# 416:	learn: 17.1712003	total: 702ms	remaining: 982ms
# 417:	learn: 17.1591720	total: 703ms	remaining: 979ms
# 418:	learn: 17.1473156	total: 705ms	remaining: 977ms
# 419:	learn: 17.1348716	total: 706ms	remaining: 975ms
# 420:	learn: 17.1229865	total: 707ms	remaining: 973ms
# 421:	learn: 17.1133897	total: 708ms	remaining: 970ms
# 422:	learn: 17.1047078	total: 710ms	remaining: 968ms
# 423:	learn: 17.0979278	total: 711ms	remaining: 966ms
# 424:	learn: 17.0855037	total: 712ms	remaining: 964ms
# 425:	learn: 17.0716778	total: 714ms	remaining: 961ms
# 426:	learn: 17.0590878	total: 715ms	remaining: 959ms
# 427:	learn: 17.0477592	total: 716ms	remaining: 957ms
# 428:	learn: 17.0326473	total: 718ms	remaining: 956ms
# 429:	learn: 17.0218248	total: 719ms	remaining: 953ms
# 430:	learn: 17.0212716	total: 720ms	remaining: 951ms
# 431:	learn: 17.0156633	total: 722ms	remaining: 949ms
# 432:	learn: 17.0116843	total: 723ms	remaining: 947ms
# 433:	learn: 16.9989022	total: 724ms	remaining: 945ms
# 434:	learn: 16.9961220	total: 726ms	remaining: 943ms
# 435:	learn: 16.9880482	total: 727ms	remaining: 941ms
# 436:	learn: 16.9844526	total: 729ms	remaining: 939ms
# 437:	learn: 16.9696929	total: 730ms	remaining: 936ms
# 438:	learn: 16.9542567	total: 731ms	remaining: 934ms
# 439:	learn: 16.9424080	total: 732ms	remaining: 932ms
# 440:	learn: 16.9307254	total: 734ms	remaining: 930ms
# 441:	learn: 16.9184493	total: 735ms	remaining: 928ms
# 442:	learn: 16.9062216	total: 736ms	remaining: 926ms
# 443:	learn: 16.9000040	total: 737ms	remaining: 923ms
# 444:	learn: 16.8900602	total: 739ms	remaining: 921ms
# 445:	learn: 16.8896272	total: 740ms	remaining: 919ms
# 446:	learn: 16.8822856	total: 741ms	remaining: 917ms
# 447:	learn: 16.8703819	total: 742ms	remaining: 915ms
# 448:	learn: 16.8600273	total: 744ms	remaining: 913ms
# 449:	learn: 16.8505914	total: 745ms	remaining: 910ms
# 450:	learn: 16.8389967	total: 746ms	remaining: 908ms
# 451:	learn: 16.8316728	total: 748ms	remaining: 906ms
# 452:	learn: 16.8197883	total: 749ms	remaining: 904ms
# 453:	learn: 16.8053175	total: 750ms	remaining: 902ms
# 454:	learn: 16.7997846	total: 751ms	remaining: 900ms
# 455:	learn: 16.7949061	total: 752ms	remaining: 898ms
# 456:	learn: 16.7855808	total: 754ms	remaining: 896ms
# 457:	learn: 16.7803270	total: 755ms	remaining: 893ms
# 458:	learn: 16.7737337	total: 756ms	remaining: 891ms
# 459:	learn: 16.7692320	total: 758ms	remaining: 889ms
# 460:	learn: 16.7686019	total: 759ms	remaining: 887ms
# 461:	learn: 16.7591282	total: 760ms	remaining: 885ms
# 462:	learn: 16.7462914	total: 761ms	remaining: 883ms
# 463:	learn: 16.7375531	total: 763ms	remaining: 881ms
# 464:	learn: 16.7308734	total: 764ms	remaining: 879ms
# 465:	learn: 16.7247088	total: 765ms	remaining: 877ms
# 466:	learn: 16.7201810	total: 766ms	remaining: 875ms
# 467:	learn: 16.7114770	total: 767ms	remaining: 872ms
# 468:	learn: 16.7008730	total: 769ms	remaining: 870ms
# 469:	learn: 16.6890596	total: 770ms	remaining: 868ms
# 470:	learn: 16.6776367	total: 771ms	remaining: 866ms
# 471:	learn: 16.6664724	total: 773ms	remaining: 864ms
# 472:	learn: 16.6597221	total: 774ms	remaining: 862ms
# 473:	learn: 16.6469349	total: 775ms	remaining: 860ms
# 474:	learn: 16.6369192	total: 777ms	remaining: 859ms
# 475:	learn: 16.6342361	total: 778ms	remaining: 857ms
# 476:	learn: 16.6295608	total: 780ms	remaining: 855ms
# 477:	learn: 16.6256026	total: 781ms	remaining: 853ms
# 478:	learn: 16.6133928	total: 782ms	remaining: 851ms
# 479:	learn: 16.6060828	total: 784ms	remaining: 849ms
# 480:	learn: 16.5910895	total: 785ms	remaining: 847ms
# 481:	learn: 16.5822173	total: 787ms	remaining: 845ms
# 482:	learn: 16.5706238	total: 788ms	remaining: 843ms
# 483:	learn: 16.5602554	total: 789ms	remaining: 841ms
# 484:	learn: 16.5492494	total: 790ms	remaining: 839ms
# 485:	learn: 16.5382274	total: 792ms	remaining: 837ms
# 486:	learn: 16.5317214	total: 793ms	remaining: 835ms
# 487:	learn: 16.5267634	total: 794ms	remaining: 833ms
# 488:	learn: 16.5217939	total: 795ms	remaining: 831ms
# 489:	learn: 16.5065649	total: 797ms	remaining: 829ms
# 490:	learn: 16.4949430	total: 798ms	remaining: 827ms
# 491:	learn: 16.4882354	total: 799ms	remaining: 825ms
# 492:	learn: 16.4817418	total: 801ms	remaining: 823ms
# 493:	learn: 16.4750329	total: 802ms	remaining: 821ms
# 494:	learn: 16.4624455	total: 803ms	remaining: 819ms
# 495:	learn: 16.4488941	total: 804ms	remaining: 817ms
# 496:	learn: 16.4402151	total: 806ms	remaining: 815ms
# 497:	learn: 16.4268925	total: 807ms	remaining: 813ms
# 498:	learn: 16.4141884	total: 808ms	remaining: 811ms
# 499:	learn: 16.4108008	total: 809ms	remaining: 809ms
# 500:	learn: 16.4016445	total: 811ms	remaining: 808ms
# 501:	learn: 16.3970803	total: 812ms	remaining: 806ms
# 502:	learn: 16.3883618	total: 813ms	remaining: 804ms
# 503:	learn: 16.3800212	total: 815ms	remaining: 802ms
# 504:	learn: 16.3679979	total: 816ms	remaining: 800ms
# 505:	learn: 16.3562425	total: 817ms	remaining: 798ms
# 506:	learn: 16.3459548	total: 819ms	remaining: 796ms
# 507:	learn: 16.3349655	total: 820ms	remaining: 794ms
# 508:	learn: 16.3240194	total: 821ms	remaining: 792ms
# 509:	learn: 16.3126029	total: 823ms	remaining: 790ms
# 510:	learn: 16.3007910	total: 824ms	remaining: 788ms
# 511:	learn: 16.2949392	total: 825ms	remaining: 786ms
# 512:	learn: 16.2902459	total: 826ms	remaining: 784ms
# 513:	learn: 16.2850277	total: 828ms	remaining: 782ms
# 514:	learn: 16.2687029	total: 829ms	remaining: 781ms
# 515:	learn: 16.2662942	total: 830ms	remaining: 779ms
# 516:	learn: 16.2608403	total: 831ms	remaining: 777ms
# 517:	learn: 16.2506376	total: 832ms	remaining: 775ms
# 518:	learn: 16.2413966	total: 834ms	remaining: 773ms
# 519:	learn: 16.2342277	total: 835ms	remaining: 771ms
# 520:	learn: 16.2233248	total: 837ms	remaining: 769ms
# 521:	learn: 16.2144406	total: 838ms	remaining: 768ms
# 522:	learn: 16.2015641	total: 840ms	remaining: 766ms
# 523:	learn: 16.1962633	total: 841ms	remaining: 764ms
# 524:	learn: 16.1935402	total: 843ms	remaining: 762ms
# 525:	learn: 16.1930978	total: 844ms	remaining: 760ms
# 526:	learn: 16.1900360	total: 845ms	remaining: 759ms
# 527:	learn: 16.1814062	total: 847ms	remaining: 757ms
# 528:	learn: 16.1774182	total: 848ms	remaining: 755ms
# 529:	learn: 16.1668788	total: 850ms	remaining: 753ms
# 530:	learn: 16.1614913	total: 851ms	remaining: 752ms
# 531:	learn: 16.1522527	total: 852ms	remaining: 750ms
# 532:	learn: 16.1426751	total: 854ms	remaining: 748ms
# 533:	learn: 16.1270909	total: 855ms	remaining: 746ms
# 534:	learn: 16.1179907	total: 857ms	remaining: 745ms
# 535:	learn: 16.1083313	total: 858ms	remaining: 743ms
# 536:	learn: 16.1027891	total: 860ms	remaining: 741ms
# 537:	learn: 16.0956992	total: 861ms	remaining: 739ms
# 538:	learn: 16.0922820	total: 863ms	remaining: 738ms
# 539:	learn: 16.0848586	total: 864ms	remaining: 736ms
# 540:	learn: 16.0799950	total: 865ms	remaining: 734ms
# 541:	learn: 16.0738186	total: 867ms	remaining: 733ms
# 542:	learn: 16.0598521	total: 868ms	remaining: 731ms
# 543:	learn: 16.0548894	total: 870ms	remaining: 729ms
# 544:	learn: 16.0485339	total: 871ms	remaining: 727ms
# 545:	learn: 16.0403855	total: 873ms	remaining: 726ms
# 546:	learn: 16.0280154	total: 874ms	remaining: 724ms
# 547:	learn: 16.0144776	total: 875ms	remaining: 722ms
# 548:	learn: 16.0067695	total: 877ms	remaining: 720ms
# 549:	learn: 15.9975179	total: 878ms	remaining: 718ms
# 550:	learn: 15.9843062	total: 880ms	remaining: 717ms
# 551:	learn: 15.9699079	total: 881ms	remaining: 715ms
# 552:	learn: 15.9575177	total: 882ms	remaining: 713ms
# 553:	learn: 15.9473444	total: 884ms	remaining: 712ms
# 554:	learn: 15.9369882	total: 885ms	remaining: 710ms
# 555:	learn: 15.9215394	total: 887ms	remaining: 708ms
# 556:	learn: 15.9134887	total: 888ms	remaining: 706ms
# 557:	learn: 15.9054776	total: 890ms	remaining: 705ms
# 558:	learn: 15.8953662	total: 891ms	remaining: 703ms
# 559:	learn: 15.8876238	total: 892ms	remaining: 701ms
# 560:	learn: 15.8777737	total: 894ms	remaining: 699ms
# 561:	learn: 15.8701311	total: 895ms	remaining: 698ms
# 562:	learn: 15.8618466	total: 897ms	remaining: 696ms
# 563:	learn: 15.8462484	total: 898ms	remaining: 694ms
# 564:	learn: 15.8369656	total: 899ms	remaining: 692ms
# 565:	learn: 15.8283609	total: 901ms	remaining: 691ms
# 566:	learn: 15.8206618	total: 902ms	remaining: 689ms
# 567:	learn: 15.8156593	total: 903ms	remaining: 687ms
# 568:	learn: 15.8110059	total: 905ms	remaining: 685ms
# 569:	learn: 15.8045846	total: 906ms	remaining: 683ms
# 570:	learn: 15.7931814	total: 907ms	remaining: 682ms
# 571:	learn: 15.7876945	total: 909ms	remaining: 680ms
# 572:	learn: 15.7812667	total: 910ms	remaining: 678ms
# 573:	learn: 15.7750935	total: 912ms	remaining: 677ms
# 574:	learn: 15.7683231	total: 913ms	remaining: 675ms
# 575:	learn: 15.7599227	total: 915ms	remaining: 673ms
# 576:	learn: 15.7567722	total: 916ms	remaining: 672ms
# 577:	learn: 15.7519242	total: 918ms	remaining: 670ms
# 578:	learn: 15.7473542	total: 919ms	remaining: 669ms
# 579:	learn: 15.7390484	total: 921ms	remaining: 667ms
# 580:	learn: 15.7349697	total: 922ms	remaining: 665ms
# 581:	learn: 15.7274394	total: 924ms	remaining: 663ms
# 582:	learn: 15.7136913	total: 925ms	remaining: 662ms
# 583:	learn: 15.7033334	total: 927ms	remaining: 660ms
# 584:	learn: 15.6955316	total: 928ms	remaining: 658ms
# 585:	learn: 15.6863023	total: 929ms	remaining: 657ms
# 586:	learn: 15.6809623	total: 931ms	remaining: 655ms
# 587:	learn: 15.6777421	total: 932ms	remaining: 653ms
# 588:	learn: 15.6715065	total: 934ms	remaining: 652ms
# 589:	learn: 15.6608195	total: 935ms	remaining: 650ms
# 590:	learn: 15.6546968	total: 937ms	remaining: 648ms
# 591:	learn: 15.6514927	total: 939ms	remaining: 647ms
# 592:	learn: 15.6511293	total: 940ms	remaining: 645ms
# 593:	learn: 15.6463517	total: 942ms	remaining: 644ms
# 594:	learn: 15.6400348	total: 943ms	remaining: 642ms
# 595:	learn: 15.6314531	total: 945ms	remaining: 641ms
# 596:	learn: 15.6278109	total: 947ms	remaining: 639ms
# 597:	learn: 15.6226696	total: 948ms	remaining: 638ms
# 598:	learn: 15.6140481	total: 950ms	remaining: 636ms
# 599:	learn: 15.6080658	total: 952ms	remaining: 635ms
# 600:	learn: 15.6024858	total: 953ms	remaining: 633ms
# 601:	learn: 15.6018805	total: 955ms	remaining: 631ms
# 602:	learn: 15.5905901	total: 956ms	remaining: 630ms
# 603:	learn: 15.5897569	total: 958ms	remaining: 628ms
# 604:	learn: 15.5804426	total: 960ms	remaining: 627ms
# 605:	learn: 15.5734230	total: 961ms	remaining: 625ms
# 606:	learn: 15.5731420	total: 963ms	remaining: 623ms
# 607:	learn: 15.5688942	total: 965ms	remaining: 622ms
# 608:	learn: 15.5620508	total: 967ms	remaining: 621ms
# 609:	learn: 15.5564956	total: 969ms	remaining: 620ms
# 610:	learn: 15.5478728	total: 971ms	remaining: 618ms
# 611:	learn: 15.5393752	total: 972ms	remaining: 616ms
# 612:	learn: 15.5367163	total: 974ms	remaining: 615ms
# 613:	learn: 15.5282839	total: 975ms	remaining: 613ms
# 614:	learn: 15.5183493	total: 977ms	remaining: 611ms
# 615:	learn: 15.5100360	total: 978ms	remaining: 610ms
# 616:	learn: 15.5014923	total: 980ms	remaining: 608ms
# 617:	learn: 15.4888642	total: 982ms	remaining: 607ms
# 618:	learn: 15.4816481	total: 984ms	remaining: 605ms
# 619:	learn: 15.4667975	total: 985ms	remaining: 604ms
# 620:	learn: 15.4538195	total: 987ms	remaining: 602ms
# 621:	learn: 15.4455945	total: 989ms	remaining: 601ms
# 622:	learn: 15.4398746	total: 991ms	remaining: 599ms
# 623:	learn: 15.4311068	total: 992ms	remaining: 598ms
# 624:	learn: 15.4236769	total: 994ms	remaining: 596ms
# 625:	learn: 15.4189249	total: 996ms	remaining: 595ms
# 626:	learn: 15.4085077	total: 997ms	remaining: 593ms
# 627:	learn: 15.4023099	total: 998ms	remaining: 591ms
# 628:	learn: 15.4019682	total: 1000ms	remaining: 590ms
# 629:	learn: 15.3916067	total: 1s	remaining: 588ms
# 630:	learn: 15.3833490	total: 1s	remaining: 587ms
# 631:	learn: 15.3797826	total: 1s	remaining: 585ms
# 632:	learn: 15.3778000	total: 1.01s	remaining: 584ms
# 633:	learn: 15.3712156	total: 1.01s	remaining: 582ms
# 634:	learn: 15.3639180	total: 1.01s	remaining: 581ms
# 635:	learn: 15.3613505	total: 1.01s	remaining: 579ms
# 636:	learn: 15.3526172	total: 1.01s	remaining: 577ms
# 637:	learn: 15.3423788	total: 1.01s	remaining: 576ms
# 638:	learn: 15.3329521	total: 1.02s	remaining: 574ms
# 639:	learn: 15.3249427	total: 1.02s	remaining: 573ms
# 640:	learn: 15.3147661	total: 1.02s	remaining: 571ms
# 641:	learn: 15.3118919	total: 1.02s	remaining: 570ms
# 642:	learn: 15.2984777	total: 1.02s	remaining: 568ms
# 643:	learn: 15.2940819	total: 1.02s	remaining: 567ms
# 644:	learn: 15.2888481	total: 1.03s	remaining: 565ms
# 645:	learn: 15.2779647	total: 1.03s	remaining: 564ms
# 646:	learn: 15.2741732	total: 1.03s	remaining: 562ms
# 647:	learn: 15.2625543	total: 1.03s	remaining: 560ms
# 648:	learn: 15.2547902	total: 1.03s	remaining: 559ms
# 649:	learn: 15.2462061	total: 1.03s	remaining: 557ms
# 650:	learn: 15.2372545	total: 1.04s	remaining: 556ms
# 651:	learn: 15.2305872	total: 1.04s	remaining: 554ms
# 652:	learn: 15.2294546	total: 1.04s	remaining: 553ms
# 653:	learn: 15.2244394	total: 1.04s	remaining: 551ms
# 654:	learn: 15.2230793	total: 1.04s	remaining: 549ms
# 655:	learn: 15.2149693	total: 1.04s	remaining: 548ms
# 656:	learn: 15.2024576	total: 1.05s	remaining: 546ms
# 657:	learn: 15.2022015	total: 1.05s	remaining: 544ms
# 658:	learn: 15.1929836	total: 1.05s	remaining: 543ms
# 659:	learn: 15.1884978	total: 1.05s	remaining: 541ms
# 660:	learn: 15.1840360	total: 1.05s	remaining: 540ms
# 661:	learn: 15.1756025	total: 1.05s	remaining: 538ms
# 662:	learn: 15.1674113	total: 1.05s	remaining: 537ms
# 663:	learn: 15.1666761	total: 1.06s	remaining: 535ms
# 664:	learn: 15.1595280	total: 1.06s	remaining: 534ms
# 665:	learn: 15.1529110	total: 1.06s	remaining: 532ms
# 666:	learn: 15.1503439	total: 1.06s	remaining: 530ms
# 667:	learn: 15.1339866	total: 1.06s	remaining: 529ms
# 668:	learn: 15.1251233	total: 1.06s	remaining: 527ms
# 669:	learn: 15.1176926	total: 1.07s	remaining: 526ms
# 670:	learn: 15.1152123	total: 1.07s	remaining: 524ms
# 671:	learn: 15.1062620	total: 1.07s	remaining: 523ms
# 672:	learn: 15.1030335	total: 1.07s	remaining: 521ms
# 673:	learn: 15.1012462	total: 1.07s	remaining: 519ms
# 674:	learn: 15.0969139	total: 1.07s	remaining: 518ms
# 675:	learn: 15.0946004	total: 1.08s	remaining: 516ms
# 676:	learn: 15.0889459	total: 1.08s	remaining: 515ms
# 677:	learn: 15.0865966	total: 1.08s	remaining: 513ms
# 678:	learn: 15.0759435	total: 1.08s	remaining: 511ms
# 679:	learn: 15.0707228	total: 1.08s	remaining: 510ms
# 680:	learn: 15.0593061	total: 1.08s	remaining: 508ms
# 681:	learn: 15.0526808	total: 1.08s	remaining: 506ms
# 682:	learn: 15.0461841	total: 1.09s	remaining: 505ms
# 683:	learn: 15.0445752	total: 1.09s	remaining: 503ms
# 684:	learn: 15.0393494	total: 1.09s	remaining: 502ms
# 685:	learn: 15.0271990	total: 1.09s	remaining: 500ms
# 686:	learn: 15.0231832	total: 1.09s	remaining: 498ms
# 687:	learn: 15.0181645	total: 1.09s	remaining: 497ms
# 688:	learn: 15.0063286	total: 1.1s	remaining: 495ms
# 689:	learn: 14.9999125	total: 1.1s	remaining: 494ms
# 690:	learn: 14.9919004	total: 1.1s	remaining: 492ms
# 691:	learn: 14.9818498	total: 1.1s	remaining: 491ms
# 692:	learn: 14.9804880	total: 1.1s	remaining: 489ms
# 693:	learn: 14.9736283	total: 1.1s	remaining: 487ms
# 694:	learn: 14.9672707	total: 1.11s	remaining: 486ms
# 695:	learn: 14.9569227	total: 1.11s	remaining: 484ms
# 696:	learn: 14.9462333	total: 1.11s	remaining: 482ms
# 697:	learn: 14.9423328	total: 1.11s	remaining: 481ms
# 698:	learn: 14.9364527	total: 1.11s	remaining: 480ms
# 699:	learn: 14.9289024	total: 1.11s	remaining: 478ms
# 700:	learn: 14.9234832	total: 1.12s	remaining: 476ms
# 701:	learn: 14.9201765	total: 1.12s	remaining: 475ms
# 702:	learn: 14.9134806	total: 1.12s	remaining: 473ms
# 703:	learn: 14.9096960	total: 1.12s	remaining: 472ms
# 704:	learn: 14.9094413	total: 1.12s	remaining: 470ms
# 705:	learn: 14.9088097	total: 1.12s	remaining: 468ms
# 706:	learn: 14.9076302	total: 1.13s	remaining: 467ms
# 707:	learn: 14.8993129	total: 1.13s	remaining: 465ms
# 708:	learn: 14.8916873	total: 1.13s	remaining: 463ms
# 709:	learn: 14.8916061	total: 1.13s	remaining: 462ms
# 710:	learn: 14.8846596	total: 1.13s	remaining: 460ms
# 711:	learn: 14.8795989	total: 1.13s	remaining: 458ms
# 712:	learn: 14.8717570	total: 1.13s	remaining: 457ms
# 713:	learn: 14.8713334	total: 1.14s	remaining: 455ms
# 714:	learn: 14.8655103	total: 1.14s	remaining: 454ms
# 715:	learn: 14.8654289	total: 1.14s	remaining: 452ms
# 716:	learn: 14.8652133	total: 1.14s	remaining: 450ms
# 717:	learn: 14.8646155	total: 1.14s	remaining: 449ms
# 718:	learn: 14.8587144	total: 1.15s	remaining: 448ms
# 719:	learn: 14.8518369	total: 1.15s	remaining: 446ms
# 720:	learn: 14.8400799	total: 1.15s	remaining: 444ms
# 721:	learn: 14.8398436	total: 1.15s	remaining: 443ms
# 722:	learn: 14.8336607	total: 1.15s	remaining: 441ms
# 723:	learn: 14.8250326	total: 1.15s	remaining: 440ms
# 724:	learn: 14.8177502	total: 1.16s	remaining: 438ms
# 725:	learn: 14.8142193	total: 1.16s	remaining: 437ms
# 726:	learn: 14.8069236	total: 1.16s	remaining: 435ms
# 727:	learn: 14.8007259	total: 1.16s	remaining: 434ms
# 728:	learn: 14.7976370	total: 1.16s	remaining: 432ms
# 729:	learn: 14.7896069	total: 1.16s	remaining: 430ms
# 730:	learn: 14.7893941	total: 1.17s	remaining: 430ms
# 731:	learn: 14.7807760	total: 1.17s	remaining: 429ms
# 732:	learn: 14.7694481	total: 1.17s	remaining: 427ms
# 733:	learn: 14.7685262	total: 1.17s	remaining: 426ms
# 734:	learn: 14.7610024	total: 1.18s	remaining: 424ms
# 735:	learn: 14.7579756	total: 1.18s	remaining: 422ms
# 736:	learn: 14.7504241	total: 1.18s	remaining: 421ms
# 737:	learn: 14.7373672	total: 1.18s	remaining: 419ms
# 738:	learn: 14.7355156	total: 1.18s	remaining: 417ms
# 739:	learn: 14.7298193	total: 1.18s	remaining: 416ms
# 740:	learn: 14.7295044	total: 1.18s	remaining: 414ms
# 741:	learn: 14.7242841	total: 1.19s	remaining: 412ms
# 742:	learn: 14.7235133	total: 1.19s	remaining: 410ms
# 743:	learn: 14.7138679	total: 1.19s	remaining: 409ms
# 744:	learn: 14.7075934	total: 1.19s	remaining: 407ms
# 745:	learn: 14.6988980	total: 1.19s	remaining: 406ms
# 746:	learn: 14.6946182	total: 1.19s	remaining: 404ms
# 747:	learn: 14.6925538	total: 1.19s	remaining: 402ms
# 748:	learn: 14.6893416	total: 1.2s	remaining: 401ms
# 749:	learn: 14.6891053	total: 1.2s	remaining: 399ms
# 750:	learn: 14.6817546	total: 1.2s	remaining: 397ms
# 751:	learn: 14.6803148	total: 1.2s	remaining: 396ms
# 752:	learn: 14.6801225	total: 1.2s	remaining: 394ms
# 753:	learn: 14.6707108	total: 1.2s	remaining: 392ms
# 754:	learn: 14.6645201	total: 1.2s	remaining: 391ms
# 755:	learn: 14.6574447	total: 1.21s	remaining: 389ms
# 756:	learn: 14.6497343	total: 1.21s	remaining: 387ms
# 757:	learn: 14.6453948	total: 1.21s	remaining: 386ms
# 758:	learn: 14.6367150	total: 1.21s	remaining: 384ms
# 759:	learn: 14.6360976	total: 1.21s	remaining: 383ms
# 760:	learn: 14.6347949	total: 1.21s	remaining: 381ms
# 761:	learn: 14.6297256	total: 1.21s	remaining: 379ms
# 762:	learn: 14.6271820	total: 1.22s	remaining: 378ms
# 763:	learn: 14.6163420	total: 1.22s	remaining: 376ms
# 764:	learn: 14.6101028	total: 1.22s	remaining: 374ms
# 765:	learn: 14.6044305	total: 1.22s	remaining: 373ms
# 766:	learn: 14.5971021	total: 1.22s	remaining: 371ms
# 767:	learn: 14.5873182	total: 1.22s	remaining: 369ms
# 768:	learn: 14.5821279	total: 1.22s	remaining: 368ms
# 769:	learn: 14.5811098	total: 1.23s	remaining: 366ms
# 770:	learn: 14.5765456	total: 1.23s	remaining: 364ms
# 771:	learn: 14.5696115	total: 1.23s	remaining: 363ms
# 772:	learn: 14.5595394	total: 1.23s	remaining: 361ms
# 773:	learn: 14.5565319	total: 1.23s	remaining: 359ms
# 774:	learn: 14.5487733	total: 1.23s	remaining: 358ms
# 775:	learn: 14.5418064	total: 1.23s	remaining: 356ms
# 776:	learn: 14.5386172	total: 1.24s	remaining: 355ms
# 777:	learn: 14.5384111	total: 1.24s	remaining: 353ms
# 778:	learn: 14.5285903	total: 1.24s	remaining: 351ms
# 779:	learn: 14.5265870	total: 1.24s	remaining: 350ms
# 780:	learn: 14.5261522	total: 1.24s	remaining: 348ms
# 781:	learn: 14.5198077	total: 1.24s	remaining: 346ms
# 782:	learn: 14.5186103	total: 1.24s	remaining: 345ms
# 783:	learn: 14.5120108	total: 1.25s	remaining: 343ms
# 784:	learn: 14.5071067	total: 1.25s	remaining: 341ms
# 785:	learn: 14.5001249	total: 1.25s	remaining: 340ms
# 786:	learn: 14.4950353	total: 1.25s	remaining: 338ms
# 787:	learn: 14.4867191	total: 1.25s	remaining: 337ms
# 788:	learn: 14.4864410	total: 1.25s	remaining: 335ms
# 789:	learn: 14.4812995	total: 1.25s	remaining: 333ms
# 790:	learn: 14.4796934	total: 1.25s	remaining: 332ms
# 791:	learn: 14.4745509	total: 1.26s	remaining: 330ms
# 792:	learn: 14.4713017	total: 1.26s	remaining: 328ms
# 793:	learn: 14.4649213	total: 1.26s	remaining: 327ms
# 794:	learn: 14.4573469	total: 1.26s	remaining: 325ms
# 795:	learn: 14.4481856	total: 1.26s	remaining: 323ms
# 796:	learn: 14.4399950	total: 1.26s	remaining: 322ms
# 797:	learn: 14.4347714	total: 1.26s	remaining: 320ms
# 798:	learn: 14.4289646	total: 1.26s	remaining: 318ms
# 799:	learn: 14.4225580	total: 1.27s	remaining: 317ms
# 800:	learn: 14.4202913	total: 1.27s	remaining: 315ms
# 801:	learn: 14.4130026	total: 1.27s	remaining: 314ms
# 802:	learn: 14.4056330	total: 1.27s	remaining: 312ms
# 803:	learn: 14.4033979	total: 1.27s	remaining: 310ms
# 804:	learn: 14.4004445	total: 1.27s	remaining: 309ms
# 805:	learn: 14.3933404	total: 1.27s	remaining: 307ms
# 806:	learn: 14.3877731	total: 1.28s	remaining: 305ms
# 807:	learn: 14.3761226	total: 1.28s	remaining: 304ms
# 808:	learn: 14.3665681	total: 1.28s	remaining: 302ms
# 809:	learn: 14.3569652	total: 1.28s	remaining: 301ms
# 810:	learn: 14.3499000	total: 1.28s	remaining: 299ms
# 811:	learn: 14.3456820	total: 1.28s	remaining: 297ms
# 812:	learn: 14.3361266	total: 1.28s	remaining: 296ms
# 813:	learn: 14.3356189	total: 1.29s	remaining: 294ms
# 814:	learn: 14.3307056	total: 1.29s	remaining: 293ms
# 815:	learn: 14.3305409	total: 1.29s	remaining: 291ms
# 816:	learn: 14.3238121	total: 1.29s	remaining: 289ms
# 817:	learn: 14.3166989	total: 1.29s	remaining: 288ms
# 818:	learn: 14.3102605	total: 1.29s	remaining: 286ms
# 819:	learn: 14.3000755	total: 1.29s	remaining: 284ms
# 820:	learn: 14.2960134	total: 1.3s	remaining: 283ms
# 821:	learn: 14.2870107	total: 1.3s	remaining: 281ms
# 822:	learn: 14.2822653	total: 1.3s	remaining: 279ms
# 823:	learn: 14.2771319	total: 1.3s	remaining: 278ms
# 824:	learn: 14.2765936	total: 1.3s	remaining: 276ms
# 825:	learn: 14.2732387	total: 1.3s	remaining: 275ms
# 826:	learn: 14.2666341	total: 1.3s	remaining: 273ms
# 827:	learn: 14.2626429	total: 1.31s	remaining: 271ms
# 828:	learn: 14.2578208	total: 1.31s	remaining: 270ms
# 829:	learn: 14.2518134	total: 1.31s	remaining: 268ms
# 830:	learn: 14.2473170	total: 1.31s	remaining: 267ms
# 831:	learn: 14.2373991	total: 1.31s	remaining: 265ms
# 832:	learn: 14.2332624	total: 1.31s	remaining: 263ms
# 833:	learn: 14.2268943	total: 1.31s	remaining: 262ms
# 834:	learn: 14.2219193	total: 1.32s	remaining: 260ms
# 835:	learn: 14.2105098	total: 1.32s	remaining: 259ms
# 836:	learn: 14.2041830	total: 1.32s	remaining: 257ms
# 837:	learn: 14.1967808	total: 1.32s	remaining: 255ms
# 838:	learn: 14.1921350	total: 1.32s	remaining: 254ms
# 839:	learn: 14.1889955	total: 1.32s	remaining: 252ms
# 840:	learn: 14.1852759	total: 1.32s	remaining: 251ms
# 841:	learn: 14.1851363	total: 1.33s	remaining: 249ms
# 842:	learn: 14.1835064	total: 1.33s	remaining: 247ms
# 843:	learn: 14.1783297	total: 1.33s	remaining: 246ms
# 844:	learn: 14.1734285	total: 1.33s	remaining: 244ms
# 845:	learn: 14.1670383	total: 1.33s	remaining: 243ms
# 846:	learn: 14.1614489	total: 1.33s	remaining: 241ms
# 847:	learn: 14.1549386	total: 1.33s	remaining: 239ms
# 848:	learn: 14.1476338	total: 1.34s	remaining: 238ms
# 849:	learn: 14.1387347	total: 1.34s	remaining: 236ms
# 850:	learn: 14.1289103	total: 1.34s	remaining: 235ms
# 851:	learn: 14.1238271	total: 1.34s	remaining: 233ms
# 852:	learn: 14.1176680	total: 1.34s	remaining: 231ms
# 853:	learn: 14.1144705	total: 1.34s	remaining: 230ms
# 854:	learn: 14.1133320	total: 1.34s	remaining: 228ms
# 855:	learn: 14.1019466	total: 1.35s	remaining: 227ms
# 856:	learn: 14.0904314	total: 1.35s	remaining: 225ms
# 857:	learn: 14.0864109	total: 1.35s	remaining: 223ms
# 858:	learn: 14.0814312	total: 1.35s	remaining: 222ms
# 859:	learn: 14.0774718	total: 1.35s	remaining: 220ms
# 860:	learn: 14.0773170	total: 1.35s	remaining: 219ms
# 861:	learn: 14.0700909	total: 1.35s	remaining: 217ms
# 862:	learn: 14.0625681	total: 1.36s	remaining: 215ms
# 863:	learn: 14.0575615	total: 1.36s	remaining: 214ms
# 864:	learn: 14.0501160	total: 1.36s	remaining: 212ms
# 865:	learn: 14.0486104	total: 1.36s	remaining: 211ms
# 866:	learn: 14.0451858	total: 1.36s	remaining: 209ms
# 867:	learn: 14.0423512	total: 1.36s	remaining: 208ms
# 868:	learn: 14.0333666	total: 1.37s	remaining: 206ms
# 869:	learn: 14.0253630	total: 1.37s	remaining: 204ms
# 870:	learn: 14.0192249	total: 1.37s	remaining: 203ms
# 871:	learn: 14.0146070	total: 1.37s	remaining: 201ms
# 872:	learn: 14.0085329	total: 1.37s	remaining: 200ms
# 873:	learn: 14.0067110	total: 1.37s	remaining: 198ms
# 874:	learn: 13.9953639	total: 1.37s	remaining: 196ms
# 875:	learn: 13.9854348	total: 1.38s	remaining: 195ms
# 876:	learn: 13.9826350	total: 1.38s	remaining: 193ms
# 877:	learn: 13.9790795	total: 1.38s	remaining: 192ms
# 878:	learn: 13.9692513	total: 1.38s	remaining: 190ms
# 879:	learn: 13.9617249	total: 1.38s	remaining: 188ms
# 880:	learn: 13.9613713	total: 1.38s	remaining: 187ms
# 881:	learn: 13.9574901	total: 1.38s	remaining: 185ms
# 882:	learn: 13.9523952	total: 1.39s	remaining: 184ms
# 883:	learn: 13.9465987	total: 1.39s	remaining: 182ms
# 884:	learn: 13.9442282	total: 1.39s	remaining: 180ms
# 885:	learn: 13.9363983	total: 1.39s	remaining: 179ms
# 886:	learn: 13.9275626	total: 1.39s	remaining: 177ms
# 887:	learn: 13.9180835	total: 1.39s	remaining: 176ms
# 888:	learn: 13.9106977	total: 1.39s	remaining: 174ms
# 889:	learn: 13.9095865	total: 1.4s	remaining: 173ms
# 890:	learn: 13.9081810	total: 1.4s	remaining: 171ms
# 891:	learn: 13.9043680	total: 1.4s	remaining: 169ms
# 892:	learn: 13.8966173	total: 1.4s	remaining: 168ms
# 893:	learn: 13.8901389	total: 1.4s	remaining: 166ms
# 894:	learn: 13.8862350	total: 1.4s	remaining: 165ms
# 895:	learn: 13.8790314	total: 1.4s	remaining: 163ms
# 896:	learn: 13.8725168	total: 1.41s	remaining: 161ms
# 897:	learn: 13.8623354	total: 1.41s	remaining: 160ms
# 898:	learn: 13.8621297	total: 1.41s	remaining: 158ms
# 899:	learn: 13.8561039	total: 1.41s	remaining: 157ms
# 900:	learn: 13.8559575	total: 1.41s	remaining: 155ms
# 901:	learn: 13.8508288	total: 1.41s	remaining: 153ms
# 902:	learn: 13.8461289	total: 1.41s	remaining: 152ms
# 903:	learn: 13.8453469	total: 1.42s	remaining: 150ms
# 904:	learn: 13.8451795	total: 1.42s	remaining: 149ms
# 905:	learn: 13.8337582	total: 1.42s	remaining: 147ms
# 906:	learn: 13.8275647	total: 1.42s	remaining: 146ms
# 907:	learn: 13.8238671	total: 1.42s	remaining: 144ms
# 908:	learn: 13.8192487	total: 1.42s	remaining: 142ms
# 909:	learn: 13.8156335	total: 1.42s	remaining: 141ms
# 910:	learn: 13.8105079	total: 1.43s	remaining: 139ms
# 911:	learn: 13.8051480	total: 1.43s	remaining: 138ms
# 912:	learn: 13.8031455	total: 1.43s	remaining: 136ms
# 913:	learn: 13.7989312	total: 1.43s	remaining: 135ms
# 914:	learn: 13.7942643	total: 1.43s	remaining: 133ms
# 915:	learn: 13.7898463	total: 1.43s	remaining: 131ms
# 916:	learn: 13.7861642	total: 1.43s	remaining: 130ms
# 917:	learn: 13.7839769	total: 1.44s	remaining: 128ms
# 918:	learn: 13.7789201	total: 1.44s	remaining: 127ms
# 919:	learn: 13.7712725	total: 1.44s	remaining: 125ms
# 920:	learn: 13.7644385	total: 1.44s	remaining: 124ms
# 921:	learn: 13.7613909	total: 1.44s	remaining: 122ms
# 922:	learn: 13.7565518	total: 1.44s	remaining: 120ms
# 923:	learn: 13.7526888	total: 1.44s	remaining: 119ms
# 924:	learn: 13.7480666	total: 1.45s	remaining: 117ms
# 925:	learn: 13.7386242	total: 1.45s	remaining: 116ms
# 926:	learn: 13.7327188	total: 1.45s	remaining: 114ms
# 927:	learn: 13.7288251	total: 1.45s	remaining: 113ms
# 928:	learn: 13.7271145	total: 1.45s	remaining: 111ms
# 929:	learn: 13.7269699	total: 1.45s	remaining: 109ms
# 930:	learn: 13.7190075	total: 1.45s	remaining: 108ms
# 931:	learn: 13.7112550	total: 1.46s	remaining: 106ms
# 932:	learn: 13.7075223	total: 1.46s	remaining: 105ms
# 933:	learn: 13.7007282	total: 1.46s	remaining: 103ms
# 934:	learn: 13.6965847	total: 1.46s	remaining: 102ms
# 935:	learn: 13.6901485	total: 1.46s	remaining: 99.9ms
# 936:	learn: 13.6822973	total: 1.46s	remaining: 98.4ms
# 937:	learn: 13.6821614	total: 1.46s	remaining: 96.8ms
# 938:	learn: 13.6729383	total: 1.47s	remaining: 95.2ms
# 939:	learn: 13.6717988	total: 1.47s	remaining: 93.7ms
# 940:	learn: 13.6706550	total: 1.47s	remaining: 92.1ms
# 941:	learn: 13.6670598	total: 1.47s	remaining: 90.5ms
# 942:	learn: 13.6618441	total: 1.47s	remaining: 88.9ms
# 943:	learn: 13.6562155	total: 1.47s	remaining: 87.4ms
# 944:	learn: 13.6475579	total: 1.47s	remaining: 85.8ms
# 945:	learn: 13.6473961	total: 1.48s	remaining: 84.2ms
# 946:	learn: 13.6414714	total: 1.48s	remaining: 82.7ms
# 947:	learn: 13.6392495	total: 1.48s	remaining: 81.1ms
# 948:	learn: 13.6355210	total: 1.48s	remaining: 79.5ms
# 949:	learn: 13.6294133	total: 1.48s	remaining: 78ms
# 950:	learn: 13.6259722	total: 1.48s	remaining: 76.4ms
# 951:	learn: 13.6190096	total: 1.48s	remaining: 74.9ms
# 952:	learn: 13.6143850	total: 1.49s	remaining: 73.3ms
# 953:	learn: 13.6113508	total: 1.49s	remaining: 71.7ms
# 954:	learn: 13.6064972	total: 1.49s	remaining: 70.2ms
# 955:	learn: 13.5984396	total: 1.49s	remaining: 68.6ms
# 956:	learn: 13.5929537	total: 1.49s	remaining: 67ms
# 957:	learn: 13.5879968	total: 1.49s	remaining: 65.5ms
# 958:	learn: 13.5827383	total: 1.49s	remaining: 63.9ms
# 959:	learn: 13.5760261	total: 1.5s	remaining: 62.3ms
# 960:	learn: 13.5737498	total: 1.5s	remaining: 60.8ms
# 961:	learn: 13.5673064	total: 1.5s	remaining: 59.2ms
# 962:	learn: 13.5648337	total: 1.5s	remaining: 57.6ms
# 963:	learn: 13.5606097	total: 1.5s	remaining: 56.1ms
# 964:	learn: 13.5554679	total: 1.5s	remaining: 54.5ms
# 965:	learn: 13.5505046	total: 1.5s	remaining: 52.9ms
# 966:	learn: 13.5399025	total: 1.5s	remaining: 51.4ms
# 967:	learn: 13.5336387	total: 1.51s	remaining: 49.8ms
# 968:	learn: 13.5315631	total: 1.51s	remaining: 48.3ms
# 969:	learn: 13.5192589	total: 1.51s	remaining: 46.7ms
# 970:	learn: 13.5157585	total: 1.51s	remaining: 45.2ms
# 971:	learn: 13.5092985	total: 1.51s	remaining: 43.6ms
# 972:	learn: 13.5069961	total: 1.51s	remaining: 42.1ms
# 973:	learn: 13.5027420	total: 1.52s	remaining: 40.5ms
# 974:	learn: 13.4971869	total: 1.52s	remaining: 38.9ms
# 975:	learn: 13.4881619	total: 1.52s	remaining: 37.4ms
# 976:	learn: 13.4796632	total: 1.52s	remaining: 35.8ms
# 977:	learn: 13.4732073	total: 1.52s	remaining: 34.3ms
# 978:	learn: 13.4674618	total: 1.52s	remaining: 32.7ms
# 979:	learn: 13.4625580	total: 1.52s	remaining: 31.1ms
# 980:	learn: 13.4622847	total: 1.53s	remaining: 29.6ms
# 981:	learn: 13.4527528	total: 1.53s	remaining: 28ms
# 982:	learn: 13.4457303	total: 1.53s	remaining: 26.5ms
# 983:	learn: 13.4455568	total: 1.53s	remaining: 24.9ms
# 984:	learn: 13.4364580	total: 1.53s	remaining: 23.3ms
# 985:	learn: 13.4308267	total: 1.53s	remaining: 21.8ms
# 986:	learn: 13.4234531	total: 1.53s	remaining: 20.2ms
# 987:	learn: 13.4184579	total: 1.54s	remaining: 18.7ms
# 988:	learn: 13.4151908	total: 1.54s	remaining: 17.1ms
# 989:	learn: 13.4090595	total: 1.54s	remaining: 15.6ms
# 990:	learn: 13.4084656	total: 1.54s	remaining: 14ms
# 991:	learn: 13.4083100	total: 1.54s	remaining: 12.4ms
# 992:	learn: 13.4009406	total: 1.54s	remaining: 10.9ms
# 993:	learn: 13.3964546	total: 1.54s	remaining: 9.33ms
# 994:	learn: 13.3866047	total: 1.55s	remaining: 7.77ms
# 995:	learn: 13.3816603	total: 1.55s	remaining: 6.22ms
# 996:	learn: 13.3768689	total: 1.55s	remaining: 4.66ms
# 997:	learn: 13.3744051	total: 1.55s	remaining: 3.11ms
# 998:	learn: 13.3709026	total: 1.55s	remaining: 1.55ms
# 999:	learn: 13.3660264	total: 1.55s	remaining: 0us
# RECM para el conjunto de entrenamiento 13.36602644666163
# RECM para el conjunto de prueba 45.007131689713795

# %% [markdown]
# Tenemos un valor de RECM de 45, el valor mas bajo de todos nuestros modelos, con un margen a nuestro favor de 3 puntos, este seria el modelo con el valor de RECM mas bajo de todos los anteriores.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# En primera instancia cargamos y realizamos el procesamiento de datos de nuestra base de datos de forma que nos fuera facil la manipulacion de fechas.
#
# Analizamos la tendencia y la estacionalidad, encontrando que tenemos un tendencia al incremente de numero de ordenes de taxis, y una estacionalidad ciclica.
#
# Realizamos una prediccion sin utilizar modelos de ML, usamos valores constantes y valor anterior a la serie, esto para darnos una idea que los valores resultantes de los modelos de ML debieran ser mejor.
#
# Realizamos la creacion de caracteristicas del dataframe, es decir, creamos columnas con el valor de año, mes, dia y hora de forma separadas, de igual forma realizamos caracteristicas de desfase y la media movil.
#
# Una vez realizado comenzamos con la realizacion y entrenamiento de los distintos modelos de regresion, LinearRegression, DecisionTreeRegressor, RandomForestRegressor, LightGBM con variante de DecissionTree y RandomForest y finalmente Catboost.
#
# Nuestra meta de RECM es de 48, en nuestros modelos obtuvimos resultados por arriba del valor de la meta lo cual no seran viables, sin embargo, obtuvimos valores favorables en ciertos modelos, pero el modelo ganador fue CatboostRegressor con el cual obtuvimos un valor de **RECM de 45**, el valor mas bajo cumpliendo la meta y el objetivo de este proyecto.
